# %% [markdown]
# ### ЗАДАЧА: Откат складских операций через стек
#
# Склад получает последовательность операций по остаткам товаров.
# Часть операций увеличивает остаток, часть уменьшает,
# а команда `undo` должна откатывать последнее успешное изменение.
#
# Нужно собрать обработчик, который:
# - меняет остатки по операциям,
# - перед каждым успешным изменением сохраняет прошлое состояние,
# - по `undo` возвращает предыдущее состояние,
# - в конце показывает итоговые остатки и историю откатов.
#
# Часть операций может пытаться списать товара больше, чем есть на складе,
# а часть команд `undo` может встретиться при пустом стеке.
# Такие ситуации не должны ломать обработку.
#
# НЕОБХОДИМО РЕАЛИЗОВАТЬ:
#
# 1. Использовать `history_stack` как стек снимков склада.
#
# 2. Поддержать команды:
#    - `add|sku|qty`,
#    - `remove|sku|qty`,
#    - `undo`,
#    - `report`.
#
# 3. Перед каждой успешной коммандой `add` или `remove` сохранять копию `stocks` в стек.
#
# 4. Если `remove` пытается увести остаток в минус, операцию не выполнять и записать ошибку в `errors`.
#
# 5. По `undo` восстанавливать последнее состояние из стека.
#
# 6. Собрать:
#    - список `snapshots` для команд `report`,
#    - количество успешных `undo`,
#    - список ошибок,
#    - финальное состояние склада.

# %%
stocks = {
    "keyboard": 10,
    "mouse": 8,
    "monitor": 4,
}

commands = [
    "remove|keyboard|2",
    "add|mouse|3",
    "report",
    "remove|monitor|5",
    "undo",
    "remove|keyboard|4",
    "report",
    "undo",
    "undo",
    "undo",
    "report",
]

history_stack = []
snapshots = []
errors = []
undo_count = 0

for command in commands:
    if command == "undo":
        # TODO 1: проверить, есть ли что откатывать (history_stack не пуст)
        # TODO 2: если есть, взять последнее состояние через pop()
        # TODO 3: присвоить stocks это состояние
        # TODO 4: увеличить undo_count на 1
        # TODO 5: если стек пуст, просто ничего не делать
        pass
        continue

    if command == "report":
        # TODO 1: сделать копию текущего словаря stocks
        # TODO 2: добавить копию в snapshots
        pass
        continue

    action, sku, qty_raw = command.split("|")
    qty = int(qty_raw)

    if action == "add":
        # TODO 1: перед изменением положить копию stocks в history_stack
        # TODO 2: увеличить остаток sku на qty
        #   подсказка: для универсальности можно использовать stocks.get(sku, 0)
        pass

    elif action == "remove":
        # TODO 1: взять текущий остаток товара (например, через stocks.get(sku, 0))
        # TODO 2: если текущий остаток < qty:
        #   - НЕ менять склад
        #   - добавить текст ошибки в errors
        # TODO 3: иначе (товара хватает):
        #   - сохранить копию stocks в history_stack
        #   - уменьшить остаток по sku на qty
        pass

print("Снимки склада:", snapshots)
print("Ошибки:", errors)
print("Успешных undo:", undo_count)
print("Финальные остатки:", stocks)
